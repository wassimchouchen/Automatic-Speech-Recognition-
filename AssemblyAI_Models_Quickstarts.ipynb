# %% [markdown]
# <a href="https://colab.research.google.com/github/wassimchouchen/Automatic-Speech-Recognition-/blob/main/AssemblyAI_Models_Quickstarts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://www.assemblyai.com/">
# <img width="300"
# src="data:image/png;base64,...">
# </a>
# </img>

# %% [markdown]
# # AssemblyAI Models Quickstart Examples
#
# The below code samples are pulled from the corresponding sections of the [AssemblyAI Documentation](https://www.assemblyai.com/docs/)

# %% [markdown]
# ## Speech Recognition

# %% [markdown]
# To run the code below, simply paste your [API token](https://www.assemblyai.com/app) into the string for the `YOUR_API_TOKEN` variable below (removing the brackets), and then press the "Play" button in the top-left hand corner of the cell.
#
# If you do not yet have an API token, you can get one for free at the link above

# %%
import requests
import json
import time

# replace with your API token
YOUR_API_TOKEN = "<YOUR_API_TOKEN>"

# URL of the file to transcribe
FILE_URL = "https://github.com/AssemblyAI-Examples/audio-examples/raw/main/20230607_me_canadian_wildfires.mp3"

# AssemblyAI transcript endpoint (where we submit the file)
transcript_endpoint = "https://api.assemblyai.com/v2/transcript"

# request parameters where Speech Recognition has been enabled
data = {
  "audio_url": FILE_URL,
}

# HTTP request headers
headers={
  "Authorization": YOUR_API_TOKEN,
  "Content-Type": "application/json"
}

# submit for transcription via HTTP request
response = requests.post(transcript_endpoint,
                         json=data,
                         headers=headers)

# polling for transcription completion
polling_endpoint = f"https://api.assemblyai.com/v2/transcript/{response.json()['id']}"

while True:
    transcription_result = requests.get(polling_endpoint, headers=headers).json()

    if transcription_result['status'] == 'completed':
        # print the results
        print(json.dumps(transcription_result, indent=2))
        break
    elif transcription_result['status'] == 'error':
        raise RuntimeError(f"Transcription failed: {transcription_result['error']}")
    else:
        time.sleep(3)
# Out:
# {
#   "id": "61q504fz9g-6e0d-4b20-954a-9aed76755654",
#   "language_model": "assemblyai_default",
#   "acoustic_model": "assemblyai_default",
#   "language_code": "en_us",
#   "status": "completed",
#   "audio_url": "https://github.com/AssemblyAI-Examples/audio-examples/raw/main/20230607_me_canadian_wildfires.mp3",
# ...

# %% [markdown]
# ## Speaker Diarization

# %% [markdown]
# To run the code below, simply paste your [API token](https://www.assemblyai.com/app) into the string for the `YOUR_API_TOKEN` variable below (removing the brackets), and then press the "Play" button in the top-left hand corner of the cell.
#
# If you do not yet have an API token, you can get one for free at the link above

# %%
import requests
import json
import time

# replace with your API token
YOUR_API_TOKEN = "6ca10e29a79e40e693187703bb686ee1"

# URL of the file to transcribe
FILE_URL = "https://github.com/AssemblyAI-Examples/audio-examples/raw/main/20230607_me_canadian_wildfires.mp3"

# AssemblyAI transcript endpoint (where we submit the file)
transcript_endpoint = "https://api.assemblyai.com/v2/transcript"

# request parameters where Speaker Diarization has been enabled
data = {
  "audio_url": FILE_URL,
  "speaker_labels": True
}

# HTTP request headers
headers={
  "Authorization": YOUR_API_TOKEN,
  "Content-Type": "application/json"
}

# submit for transcription via HTTP request
response = requests.post(transcript_endpoint,
                         json=data,
                         headers=headers)

# polling for transcription completion
polling_endpoint = f"https://api.assemblyai.com/v2/transcript/{response.json()['id']}"

while True:
    transcription_result = requests.get(polling_endpoint, headers=headers).json()

    if transcription_result['status'] == 'completed':
        # print the results
        print(json.dumps(transcription_result, indent=2))
        break
    elif transcription_result['status'] == 'error':
        raise RuntimeError(f"Transcription failed: {transcription_result['error']}")
    else:
        time.sleep(3)
# Out:
# {
#   "id": "607q9wq55x-98f0-4264-893e-bca9045c0222",
#   "language_model": "assemblyai_default",
#   "acoustic_model": "assemblyai_default",
#   "language_code": "en_us",
#   "status": "completed",
#   "audio_url": "https://github.com/AssemblyAI-Examples/audio-examples/raw/main/20230607_me_canadian_wildfires.mp3",
# ...

# %% [markdown]
# ## Summarization

# %% [markdown]
# To run the code below, simply paste your [API token](https://www.assemblyai.com/app) into the string for the `YOUR_API_TOKEN` variable below (removing the brackets), and then press the "Play" button in the top-left hand corner of the cell.
#
# If you do not yet have an API token, you can get one for free at the link above

# %%
import requests
import json
import time

# replace with your API token
YOUR_API_TOKEN = "<YOUR_API_TOKEN>"

# URL of the file to transcribe
FILE_URL = "https://github.com/AssemblyAI-Examples/audio-examples/raw/main/20230607_me_canadian_wildfires.mp3"

# AssemblyAI transcript endpoint (where we submit the file)
transcript_endpoint = "https://api.assemblyai.com/v2/transcript"

# request parameters where Summarization has been enabled
data = {
  "audio_url": FILE_URL,
  "summarization": True,
  "summary_model": "informative",
  "summary_type": "bullets"
}

# HTTP request headers
headers={
  "Authorization": YOUR_API_TOKEN,
  "Content-Type": "application/json"
}

# submit for transcription via HTTP request
response = requests.post(transcript_endpoint,
                         json=data,
                         headers=headers)

# polling for transcription completion
polling_endpoint = f"https://api.assemblyai.com/v2/transcript/{response.json()['id']}"

while True:
    transcription_result = requests.get(polling_endpoint, headers=headers).json()

    if transcription_result['status'] == 'completed':
        # print the results
        print(json.dumps(transcription_result, indent=2))
        break
    elif transcription_result['status'] == 'error':
        raise RuntimeError(f"Transcription failed: {transcription_result['error']}")
    else:
        time.sleep(3)
# Out:
# {
#   "id": "61q5pj28jk-9b9e-492d-8900-8b81a28df9fa",
#   "language_model": "assemblyai_default",
#   "acoustic_model": "assemblyai_default",
#   "language_code": "en_us",
#   "status": "completed",
#   "audio_url": "https://github.com/AssemblyAI-Examples/audio-examples/raw/main/20230607_me_canadian_wildfires.mp3",
# ...

# %% [markdown]
# ## Content Moderation

# %% [markdown]
# To run the code below, simply paste your [API token](https://www.assemblyai.com/app) into the string for the `YOUR_API_TOKEN` variable below (removing the brackets), and then press the "Play" button in the top-left hand corner of the cell.
#
# If you do not yet have an API token, you can get one for free at the link above

# %%
import requests
import json
import time

# replace with your API token
YOUR_API_TOKEN = "<YOUR_API_TOKEN>"

# URL of the file to transcribe
FILE_URL = "https://github.com/AssemblyAI-Examples/audio-examples/raw/main/20230607_me_canadian_wildfires.mp3"

# AssemblyAI transcript endpoint (where we submit the file)
transcript_endpoint = "https://api.assemblyai.com/v2/transcript"

# request parameters where Content Moderation has been enabled
data = {
  "audio_url": FILE_URL,
  "content_safety": True
}

# HTTP request headers
headers={
  "Authorization": YOUR_API_TOKEN,
  "Content-Type": "application/json"
}

# submit for transcription via HTTP request
response = requests.post(transcript_endpoint,
                         json=data,
                         headers=headers)

# polling for transcription completion
polling_endpoint = f"https://api.assemblyai.com/v2/transcript/{response.json()['id']}"

while True:
    transcription_result = requests.get(polling_endpoint, headers=headers).json()

    if transcription_result['status'] == 'completed':
        # print the results
        print(json.dumps(transcription_result, indent=2))
        break
    elif transcription_result['status'] == 'error':
        raise RuntimeError(f"Transcription failed: {transcription_result['error']}")
    else:
        time.sleep(3)
# Out:
# {
#   "id": "61q5fcjtzv-bcc3-4c5e-908f-4f74990231f2",
#   "language_model": "assemblyai_default",
#   "acoustic_model": "assemblyai_default",
#   "language_code": "en_us",
#   "status": "completed",
#   "audio_url": "https://github.com/AssemblyAI-Examples/audio-examples/raw/main/20230607_me_canadian_wildfires.mp3",
# ...

# %% [markdown]
# ## Sentiment Analysis

# %% [markdown]
# To run the code below, simply paste your [API token](https://www.assemblyai.com/app) into the string for the `YOUR_API_TOKEN` variable below (removing the brackets), and then press the "Play" button in the top-left hand corner of the cell.
#
# If you do not yet have an API token, you can get one for free at the link above

# %%
import requests
import json
import time

# replace with your API token
YOUR_API_TOKEN = "<YOUR_API_TOKEN>"

# URL of the file to transcribe
FILE_URL = "https://github.com/AssemblyAI-Examples/audio-examples/raw/main/20230607_me_canadian_wildfires.mp3"

# AssemblyAI transcript endpoint (where we submit the file)
transcript_endpoint = "https://api.assemblyai.com/v2/transcript"

# request parameters where Sentiment Analysis has been enabled
data = {
  "audio_url": FILE_URL,
  "sentiment_analysis": True
}

# HTTP request headers
headers={
  "Authorization": YOUR_API_TOKEN,
  "Content-Type": "application/json"
}

# submit for transcription via HTTP request
response = requests.post(transcript_endpoint,
                         json=data,
                         headers=headers)

# polling for transcription completion
polling_endpoint = f"https://api.assemblyai.com/v2/transcript/{response.json()['id']}"

while True:
    transcription_result = requests.get(polling_endpoint, headers=headers).json()

    if transcription_result['status'] == 'completed':
        # print the results
        print(json.dumps(transcription_result, indent=2))
        break
    elif transcription_result['status'] == 'error':
        raise RuntimeError(f"Transcription failed: {transcription_result['error']}")
    else:
        time.sleep(3)
# Out:
# {
#   "id": "61q9rbxptr-abdf-4fe0-9517-890ab5e5f392",
#   "language_model": "assemblyai_default",
#   "acoustic_model": "assemblyai_default",
#   "language_code": "en_us",
#   "status": "completed",
#   "audio_url": "https://github.com/AssemblyAI-Examples/audio-examples/raw/main/20230607_me_canadian_wildfires.mp3",
# ...

# %% [markdown]
# ## Entity Detection

# %% [markdown]
# To run the code below, simply paste your [API token](https://www.assemblyai.com/app) into the string for the `YOUR_API_TOKEN` variable below (removing the brackets), and then press the "Play" button in the top-left hand corner of the cell.
#
# If you do not yet have an API token, you can get one for free at the link above

# %%
import requests
import json
import time

# replace with your API token
YOUR_API_TOKEN = "<YOUR_API_TOKEN>"

# URL of the file to transcribe
FILE_URL = "https://github.com/AssemblyAI-Examples/audio-examples/raw/main/20230607_me_canadian_wildfires.mp3"

# AssemblyAI transcript endpoint (where we submit the file)
transcript_endpoint = "https://api.assemblyai.com/v2/transcript"

# request parameters where Entity Detection has been enabled
data = {
  "audio_url": FILE_URL,
  "entity_detection": True
}

# HTTP request headers
headers={
  "Authorization": YOUR_API_TOKEN,
  "Content-Type": "application/json"
}

# submit for transcription via HTTP request
response = requests.post(transcript_endpoint,
                         json=data,
                         headers=headers)

# polling for transcription completion
polling_endpoint = f"https://api.assemblyai.com/v2/transcript/{response.json()['id']}"

while True:
    transcription_result = requests.get(polling_endpoint, headers=headers).json()

    if transcription_result['status'] == 'completed':
        # print the results
        print(json.dumps(transcription_result, indent=2))
        break
    elif transcription_result['status'] == 'error':
        raise RuntimeError(f"Transcription failed: {transcription_result['error']}")
    else:
        time.sleep(3)
# Out:
# {
#   "id": "61q9zzqzlk-d9d2-4f89-ade8-5603a8e7cd87",
#   "language_model": "assemblyai_default",
#   "acoustic_model": "assemblyai_default",
#   "language_code": "en_us",
#   "status": "completed",
#   "audio_url": "https://github.com/AssemblyAI-Examples/audio-examples/raw/main/20230607_me_canadian_wildfires.mp3",
# ...

# %% [markdown]
# ## PII Redaction

# %% [markdown]
# To run the code below, simply paste your [API token](https://www.assemblyai.com/app) into the string for the `YOUR_API_TOKEN` variable below (removing the brackets), and then press the "Play" button in the top-left hand corner of the cell.
#
# If you do not yet have an API token, you can get one for free at the link above

# %%
import requests
import json
import time

# replace with your API token
YOUR_API_TOKEN = "<YOUR_API_TOKEN>"

# URL of the file to transcribe
FILE_URL = "https://github.com/AssemblyAI-Examples/audio-examples/raw/main/20230607_me_canadian_wildfires.mp3"

# AssemblyAI transcript endpoint (where we submit the file)
transcript_endpoint = "https://api.assemblyai.com/v2/transcript"

# request parameters where PII Redaction has been enabled
data = {
  "audio_url": FILE_URL,
  "redact_pii": True,
  "redact_pii_policies": ["us_social_security_number", "credit_card_number"]
}

# HTTP request headers
headers={
  "Authorization": YOUR_API_TOKEN,
  "Content-Type": "application/json"
}

# submit for transcription via HTTP request
response = requests.post(transcript_endpoint,
                         json=data,
                         headers=headers)

# polling for transcription completion
polling_endpoint = f"https://api.assemblyai.com/v2/transcript/{response.json()['id']}"

while True:
    transcription_result = requests.get(polling_endpoint, headers=headers).json()

    if transcription_result['status'] == 'completed':
        # print the results
        print(json.dumps(transcription_result, indent=2))
        break
    elif transcription_result['status'] == 'error':
        raise RuntimeError(f"Transcription failed: {transcription_result['error']}")
    else:
        time.sleep(3)
# Out:
# {
#   "id": "61q90s0c5y-a7d8-462e-9dd5-331852a90e22",
#   "language_model": "assemblyai_default",
#   "acoustic_model": "assemblyai_default",
#   "language_code": "en_us",
#   "status": "completed",
#   "audio_url": "https://github.com/AssemblyAI-Examples/audio-examples/raw/main/20230607_me_canadian_wildfires.mp3",
# ...

# %% [markdown]
# ## Topic Detection

# %% [markdown]
# To run the code below, simply paste your [API token](https://www.assemblyai.com/app) into the string for the `YOUR_API_TOKEN` variable below (removing the brackets), and then press the "Play" button in the top-left hand corner of the cell.
#
# If you do not yet have an API token, you can get one for free at the link above

# %%
import requests
import json
import time

# replace with your API token
YOUR_API_TOKEN = "<YOUR_API_TOKEN>"

# URL of the file to transcribe
FILE_URL = "https://github.com/AssemblyAI-Examples/audio-examples/raw/main/20230607_me_canadian_wildfires.mp3"

# AssemblyAI transcript endpoint (where we submit the file)
transcript_endpoint = "https://api.assemblyai.com/v2/transcript"

# request parameters where Topic Detection has been enabled
data = {
  "audio_url": FILE_URL,
  "iab_categories": True
}

# HTTP request headers
headers={
  "Authorization": YOUR_API_TOKEN,
  "Content-Type": "application/json"
}

# submit for transcription via HTTP request
response = requests.post(transcript_endpoint,
                         json=data,
                         headers=headers)

# polling for transcription completion
polling_endpoint = f"https://api.assemblyai.com/v2/transcript/{response.json()['id']}"

while True:
    transcription_result = requests.get(polling_endpoint, headers=headers).json()

    if transcription_result['status'] == 'completed':
        # print the results
        print(json.dumps(transcription_result, indent=2))
        break
    elif transcription_result['status'] == 'error':
        raise RuntimeError(f"Transcription failed: {transcription_result['error']}")
    else:
        time.sleep(3)
# Out:
# {
#   "id": "61q9u5xrxs-46bd-457e-bffc-d6061ba8dfc3",
#   "language_model": "assemblyai_default",
#   "acoustic_model": "assemblyai_default",
#   "language_code": "en_us",
#   "status": "completed",
#   "audio_url": "https://github.com/AssemblyAI-Examples/audio-examples/raw/main/20230607_me_canadian_wildfires.mp3",
# ...

# %% [markdown]
# ## Auto Chapters

# %% [markdown]
# To run the code below, simply paste your [API token](https://www.assemblyai.com/app) into the string for the `YOUR_API_TOKEN` variable below (removing the brackets), and then press the "Play" button in the top-left hand corner of the cell.
#
# If you do not yet have an API token, you can get one for free at the link above

# %%
import requests
import json
import time

# replace with your API token
YOUR_API_TOKEN = "<YOUR_API_TOKEN>"

# URL of the file to transcribe
FILE_URL = "https://github.com/AssemblyAI-Examples/audio-examples/raw/main/20230607_me_canadian_wildfires.mp3"

# AssemblyAI transcript endpoint (where we submit the file)
transcript_endpoint = "https://api.assemblyai.com/v2/transcript"

# request parameters where Auto Chapters has been enabled
data = {
  "audio_url": FILE_URL,
  "auto_chapters": True,
  "punctuate": True
}

# HTTP request headers
headers={
  "Authorization": YOUR_API_TOKEN,
  "Content-Type": "application/json"
}

# submit for transcription via HTTP request
response = requests.post(transcript_endpoint,
                         json=data,
                         headers=headers)

# polling for transcription completion
polling_endpoint = f"https://api.assemblyai.com/v2/transcript/{response.json()['id']}"

while True:
    transcription_result = requests.get(polling_endpoint, headers=headers).json()

    if transcription_result['status'] == 'completed':
        # print the results
        print(json.dumps(transcription_result, indent=2))
        break
    elif transcription_result['status'] == 'error':
        raise RuntimeError(f"Transcription failed: {transcription_result['error']}")
    else:
        time.sleep(3)
# Out:
# {
#   "id": "61q9pqi3uw-5d47-4d10-a0d0-4b1e859848e9",
#   "language_model": "assemblyai_default",
#   "acoustic_model": "assemblyai_default",
#   "language_code": "en_us",
#   "status": "completed",
#   "audio_url": "https://github.com/AssemblyAI-Examples/audio-examples/raw/main/20230607_me_canadian_wildfires.mp3",
# ...

# %% [markdown]
# ## Key Phrases

# %% [markdown]
# To run the code below, simply paste your [API token](https://www.assemblyai.com/app) into the string for the `YOUR_API_TOKEN` variable below (removing the brackets), and then press the "Play" button in the top-left hand corner of the cell.
#
# If you do not yet have an API token, you can get one for free at the link above

# %%
import requests
import json
import time

# replace with your API token
YOUR_API_TOKEN = "<YOUR_API_TOKEN>"

# URL of the file to transcribe
FILE_URL = "https://github.com/AssemblyAI-Examples/audio-examples/raw/main/20230607_me_canadian_wildfires.mp3"

# AssemblyAI transcript endpoint (where we submit the file)
transcript_endpoint = "https://api.assemblyai.com/v2/transcript"

# request parameters where Key Phrases has been enabled
data = {
  "audio_url": FILE_URL,
  "auto_highlights": True
}

# HTTP request headers
headers={
  "Authorization": YOUR_API_TOKEN,
  "Content-Type": "application/json"
}

# submit for transcription via HTTP request
response = requests.post(transcript_endpoint,
                         json=data,
                         headers=headers)

# polling for transcription completion
polling_endpoint = f"https://api.assemblyai.com/v2/transcript/{response.json()['id']}"

while True:
    transcription_result = requests.get(polling_endpoint, headers=headers).json()

    if transcription_result['status'] == 'completed':
        # print the results
        print(json.dumps(transcription_result, indent=2))
        break
    elif transcription_result['status'] == 'error':
        raise RuntimeError(f"Transcription failed: {transcription_result['error']}")
    else:
        time.sleep(3)
# Out:
# {
#   "id": "61q9w54yzn-50fa-4b19-b6ee-9dcbd444795c",
#   "language_model": "assemblyai_default",
#   "acoustic_model": "assemblyai_default",
#   "language_code": "en_us",
#   "status": "completed",
#   "audio_url": "https://github.com/AssemblyAI-Examples/audio-examples/raw/main/20230607_me_canadian_wildfires.mp3",
# ...
